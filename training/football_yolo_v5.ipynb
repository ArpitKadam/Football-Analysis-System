# %%
from dotenv import load_dotenv
import os
load_dotenv()

api = os.getenv('ROBOFLOW_API_KEY')

# %%
from roboflow import Roboflow

rf = Roboflow(api_key=api)
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
dataset.location
# Out:
# 'c:\\Users\\arpit\\OneDrive\\Desktop\\Football_Analysis\\training\\football-players-detection-1'

# %%
import torch
print(torch.version.cuda)  # Shows CUDA version used by PyTorch
# Out:
# 12.6

# %%
import torch
print(torch.cuda.is_available())  # Should print True
print(torch.cuda.device_count())  # Should be > 0
print(torch.cuda.get_device_name(0))  # Should print your GPU name
# Out:
# True
# 1
# NVIDIA GeForce RTX 3050 Laptop GPU

# %% [markdown]
# # TRAINING

# %%
# !yolo task=detect mode=train model=yolov5xu.pt data={dataset.location}/data.yaml epochs=100 imgsz=640 batch=8 device=0
# Out:
# Ultralytics 8.3.91 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...
